# %%
import pandas as pd

df = pd.read_csv('NBA_season1718_salary.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 573 entries, 0 to 572
# Data columns (total 4 columns):
# Unnamed: 0     573 non-null int64
# Player         573 non-null object
# Tm             573 non-null object
# season17_18    573 non-null float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 18.0+ KB

# %%
df.head()
# Out:
#    Unnamed: 0          Player   Tm  season17_18
# 0           1   Stephen Curry  GSW   34682550.0
# 1           2    LeBron James  CLE   33285709.0
# 2           3    Paul Millsap  DEN   31269231.0
# 3           4  Gordon Hayward  BOS   29727900.0
# 4           5   Blake Griffin  DET   29512900.0

# %%
df1 = pd.read_excel('2019_Data_Professional_Salary_Survey_Responses.xlsx')

# %%
df1.columns
# Out:
# Index(['This data is from the 2017/2018/2019 Data Professional Salary Survey. For more details and analysis, visit:',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22',
#        'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26',
#        'Unnamed: 27', 'Unnamed: 28'],
#       dtype='object')

# %%
df1.head()
# Out:
#   This data is from the 2017/2018/2019 Data Professional Salary Survey. For more details and analysis, visit:  \
# 0                https://www.BrentOzar.com/go/salary
# 1                                                NaN
# 2                                        Survey Year
# 3                                               2017
# 4                                               2017
#
#                    Unnamed: 1 Unnamed: 2      Unnamed: 3  Unnamed: 4  \
# 0                         NaN        NaN             NaN         NaN
# 1                         NaN        NaN             NaN         NaN
# 2                   Timestamp  SalaryUSD         Country  PostalCode
# 3  2017-01-05 05:10:20.451000     200000   United States   Not Asked
# 4  2017-01-05 05:26:23.388000      61515  United Kingdom   Not Asked
#
#              Unnamed: 5             Unnamed: 6          Unnamed: 7  \
# 0                   NaN                    NaN                 NaN
# ...

# %%
df1.head(20)
# Out:
#    This data is from the 2017/2018/2019 Data Professional Salary Survey. For more details and analysis, visit:  \
# 0                 https://www.BrentOzar.com/go/salary
# 1                                                 NaN
# 2                                         Survey Year
# 3                                                2017
# 4                                                2017
# 5                                                2017
# 6                                                2017
# 7                                                2017
# 8                                                2017
# 9                                                2017
# 10                                               2017
# 11                                               2017
# 12                                               2017
# 13                                               2017
# 14                                               2017
# ...

# %%
df1.rename(columns={'This data is from the 2017/2018/2019 Data Professional Salary Survey. For more details and analysis, visit:' : 'year', 
                   'Unnamed: 1' : 'Date', 'Unnamed: 2' : 'Salary_USD', 'Unnamed: 3': 'Country', 'Unnamed: 4' : 'Postcode', 'Unnamed: 5' : 'Primary_Database'}, inplace =True)

# %%
df1.rename(columns={'Unnamed: 6' : 'YearsWithThisDatabase', 'Unnamed: 7' : 'OtherDatabases', 'Unnamed: 8': 'EmploymentStatus' ,
                   'Unnamed: 9' : 'JobTitle', 'Unnamed: 19' : 'Hours'}, inplace = True)

# %%
df1.columns
# Out:
# Index(['year', 'Date', 'Salary_USD', 'Country', 'Postcode', 'Primary_Database',
#        'YearsWithThisDatabase', 'OtherDatabases', 'EmploymentStatus',
#        'JobTitle', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Hours', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22',
#        'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26',
#        'Unnamed: 27', 'Unnamed: 28'],
#       dtype='object')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6896 entries, 0 to 6895
# Data columns (total 29 columns):
# year                     6895 non-null object
# Date                     6894 non-null object
# Salary_USD               6894 non-null object
# Country                  6894 non-null object
# Postcode                 5935 non-null object
# Primary_Database         6894 non-null object
# YearsWithThisDatabase    6894 non-null object
# OtherDatabases           5521 non-null object
# EmploymentStatus         6894 non-null object
# JobTitle                 6894 non-null object
# Unnamed: 10              6894 non-null object
# Unnamed: 11              6894 non-null object
# Unnamed: 12              6894 non-null object
# Unnamed: 13              6894 non-null object
# Unnamed: 14              6894 non-null object
# Unnamed: 15              6894 non-null object
# Unnamed: 16              6894 non-null object
# Unnamed: 17              5678 non-null object
# ...

# %%
pd.set_option('display.max_columns', 500)

# %%
df1.columns
# Out:
# Index(['year', 'Date', 'Salary_USD', 'Country', 'Postcode', 'Primary_Database',
#        'YearsWithThisDatabase', 'OtherDatabases', 'EmploymentStatus',
#        'JobTitle', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Hours', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22',
#        'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26',
#        'Unnamed: 27', 'Unnamed: 28'],
#       dtype='object')

# %%
df1.head()
# Out:
#                                   year                        Date Salary_USD  \
# 0  https://www.BrentOzar.com/go/salary                         NaN        NaN
# 1                                  NaN                         NaN        NaN
# 2                          Survey Year                   Timestamp  SalaryUSD
# 3                                 2017  2017-01-05 05:10:20.451000     200000
# 4                                 2017  2017-01-05 05:26:23.388000      61515
#
#           Country    Postcode      Primary_Database  YearsWithThisDatabase  \
# 0             NaN         NaN                   NaN                    NaN
# 1             NaN         NaN                   NaN                    NaN
# 2         Country  PostalCode       PrimaryDatabase  YearsWithThisDatabase
# 3   United States   Not Asked  Microsoft SQL Server                     10
# 4  United Kingdom   Not Asked  Microsoft SQL Server                     15
#
# ...

# %%
df1.rename(columns={'Unnamed: 11' : 'YearsatCompany', 'Unnamed: 10': 'Manage', 'Unnamed: 13' : 'Teamsize', 'Unnamed: 15' : 'Servers'}, inplace=True)

# %%
dfreg = df1.drop(columns=['Unnamed: 14',  'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
       'Hours', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
       'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27',
       'Unnamed: 28'], axis=1)

# %%
df1.columns
# Out:
# Index(['year', 'Date', 'Salary_USD', 'Country', 'Postcode', 'Primary_Database',
#        'YearsWithThisDatabase', 'OtherDatabases', 'EmploymentStatus',
#        'JobTitle', 'Manage', 'YearsatCompany', 'Unnamed: 12', 'Teamsize',
#        'Unnamed: 14', 'Servers', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Hours', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27',
#        'Unnamed: 28'],
#       dtype='object')

# %%
dfreg
# Out:
#                                      year                        Date  \
# 0     https://www.BrentOzar.com/go/salary                         NaN
# 1                                     NaN                         NaN
# 2                             Survey Year                   Timestamp
# 3                                    2017  2017-01-05 05:10:20.451000
# 4                                    2017  2017-01-05 05:26:23.388000
# 5                                    2017  2017-01-05 05:32:57.367000
# 6                                    2017  2017-01-05 05:33:03.316000
# 7                                    2017  2017-01-05 05:34:33.866000
# 8                                    2017  2017-01-05 06:05:47.744000
# 9                                    2017  2017-01-05 06:09:50.455000
# 10                                   2017  2017-01-05 06:34:59.470000
# 11                                   2017  2017-01-05 06:43:23.462000
# ...

# %%
dfreg =dfreg.drop([0,2], axis=0)

# %%
dfreg.dropna(inplace=True)

# %%
dfreg
# Out:
#       year                        Date Salary_USD         Country   Postcode  \
# 3     2017  2017-01-05 05:10:20.451000     200000   United States  Not Asked
# 4     2017  2017-01-05 05:26:23.388000      61515  United Kingdom  Not Asked
# 5     2017  2017-01-05 05:32:57.367000      95000         Germany  Not Asked
# 7     2017  2017-01-05 05:34:33.866000      35000          France  Not Asked
# 9     2017  2017-01-05 06:09:50.455000      75000         Germany  Not Asked
# 10    2017  2017-01-05 06:34:59.470000      47000     Netherlands  Not Asked
# 11    2017  2017-01-05 06:43:23.462000      41000  United Kingdom  Not Asked
# 12    2017  2017-01-05 07:03:53.669000      51652  United Kingdom  Not Asked
# 14    2017  2017-01-05 07:10:54.633000      60000         Belgium  Not Asked
# 15    2017  2017-01-05 07:22:44.428000     137500   United States  Not Asked
# 16    2017  2017-01-05 07:23:58.908000      63000  United Kingdom  Not Asked
# ...

# %%
dfreg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4736 entries, 3 to 6890
# Data columns (total 15 columns):
# year                     4736 non-null object
# Date                     4736 non-null object
# Salary_USD               4736 non-null object
# Country                  4736 non-null object
# Postcode                 4736 non-null object
# Primary_Database         4736 non-null object
# YearsWithThisDatabase    4736 non-null object
# OtherDatabases           4736 non-null object
# EmploymentStatus         4736 non-null object
# JobTitle                 4736 non-null object
# Manage                   4736 non-null object
# YearsatCompany           4736 non-null object
# Unnamed: 12              4736 non-null object
# Teamsize                 4736 non-null object
# Servers                  4736 non-null object
# dtypes: object(15)
# memory usage: 592.0+ KB

# %%
dfreg['year'] = pd.to_datetime(dfreg['year'])

# %%
dfreg['Date'] = pd.to_datetime(dfreg['Date'])

# %%
#dfreg['Salary_USD'] = dfreg['Salary_USD'].astype(float)
dfreg['YearsWithThisDatabase'] = dfreg['YearsWithThisDatabase'].astype(float)
dfreg['YearsatCompany'] = dfreg['YearsatCompany'].astype(float)
#dfreg['Teamsize'] = dfreg['Teamsize'].astype(float)
dfreg['Servers'] = dfreg['Servers'].astype(float)

# %%
dfreg['Salary_USD'].describe()
# Out:
# count       4736
# unique       912
# top       100000
# freq         132
# Name: Salary_USD, dtype: int64

# %%
dfreg['Salary_USD'] = dfreg['Salary_USD'].astype(float)

# %%
dfreg['Salary_USD'].value_counts()
# Out:
# 100000.00    132
# 110000.00    131
# 120000.00    128
# 90000.00     113
# 115000.00    104
# 95000.00     104
# 125000.00    103
# 80000.00      98
# 105000.00     97
# 85000.00      94
# 130000.00     93
# 65000.00      84
# 75000.00      79
# 70000.00      74
# 135000.00     67
# 60000.00      63
# 140000.00     50
# 98000.00      45
# 150000.00     43
# 72000.00      41
# 55000.00      41
# 92000.00      40
# 160000.00     39
# 108000.00     39
# 96000.00      37
# 103000.00     37
# 88000.00      36
# 102000.00     35
# 84000.00      35
# 93000.00      35
#             ...
# 5214.00        1
# 99348.12       1
# 167000.00      1
# 60500.00       1
# 89167.00       1
# 103250.00      1
# 70800.00       1
# 55845.00       1
# 31893.00       1
# 37400.00       1
# 50400.00       1
# 130271.00      1
# 50393.00       1
# 85585.00       1
# 17621.00       1
# 93396.00       1
# 81100.00       1
# 62666.00       1
# 70850.00       1
# 41900.00       1
# 87227.00       1
# ...

# %%
dfreg['Salary_USD'].replace(' ', '.', regex=True, inplace=True)

# %%
dfreg['Salary_USD'].replace(',', '', regex=True, inplace=True)

# %%
dfreg['Teamsize'].describe()
# Out:
# count     4736
# unique       7
# top       None
# freq      1872
# Name: Teamsize, dtype: object

# %%
dfreg['Teamsize'].value_counts()
# Out:
# None           1872
# 1               997
# 2               585
# More than 5     472
# 3               398
# 4               246
# 5               166
# Name: Teamsize, dtype: int64

# %%
dfreg['Teamsize'].replace('None',0, inplace=True)
dfreg['Teamsize'].replace('More than 5',6, inplace=True)

# %%
dtypes(dfreg['Teamsize'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-3dbb109cf057> in <module>()
# ----> 1 dtypes(dfreg['Teamsize'])
#
# NameError: name 'dtypes' is not defined

# %%
dfreg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4736 entries, 3 to 6890
# Data columns (total 15 columns):
# year                     4736 non-null datetime64[ns]
# Date                     4736 non-null datetime64[ns]
# Salary_USD               4736 non-null float64
# Country                  4736 non-null object
# Postcode                 4736 non-null object
# Primary_Database         4736 non-null object
# YearsWithThisDatabase    4736 non-null float64
# OtherDatabases           4736 non-null object
# EmploymentStatus         4736 non-null object
# JobTitle                 4736 non-null object
# Manage                   4736 non-null object
# YearsatCompany           4736 non-null float64
# Unnamed: 12              4736 non-null object
# Teamsize                 4736 non-null int64
# Servers                  4736 non-null float64
# dtypes: datetime64[ns](2), float64(4), int64(1), object(8)
# memory usage: 592.0+ KB

# %%
dfreg = dfreg.drop(columns=['Unnamed: 12'], axis=1)

# %%
dfreg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4736 entries, 3 to 6890
# Data columns (total 14 columns):
# year                     4736 non-null datetime64[ns]
# Date                     4736 non-null datetime64[ns]
# Salary_USD               4736 non-null float64
# Country                  4736 non-null object
# Postcode                 4736 non-null object
# Primary_Database         4736 non-null object
# YearsWithThisDatabase    4736 non-null float64
# OtherDatabases           4736 non-null object
# EmploymentStatus         4736 non-null object
# JobTitle                 4736 non-null object
# Manage                   4736 non-null object
# YearsatCompany           4736 non-null float64
# Teamsize                 4736 non-null int64
# Servers                  4736 non-null float64
# dtypes: datetime64[ns](2), float64(4), int64(1), object(7)
# memory usage: 555.0+ KB

# %%
dfreg['Manage'].describe()
# Out:
# count     4736
# unique       2
# top         No
# freq      3585
# Name: Manage, dtype: object

# %%
dfreg['Manage'].replace('Yes',1, inplace=True)
dfreg['Manage'].replace('No', 0, inplace=True)

# %%
dfreg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4736 entries, 3 to 6890
# Data columns (total 14 columns):
# year                     4736 non-null datetime64[ns]
# Date                     4736 non-null datetime64[ns]
# Salary_USD               4736 non-null float64
# Country                  4736 non-null object
# Postcode                 4736 non-null object
# Primary_Database         4736 non-null object
# YearsWithThisDatabase    4736 non-null float64
# OtherDatabases           4736 non-null object
# EmploymentStatus         4736 non-null object
# JobTitle                 4736 non-null object
# Manage                   4736 non-null int64
# YearsatCompany           4736 non-null float64
# Teamsize                 4736 non-null int64
# Servers                  4736 non-null float64
# dtypes: datetime64[ns](2), float64(4), int64(2), object(6)
# memory usage: 555.0+ KB

# %%
import seaborn as sns

# %%
sns.pairplot(dfreg)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize = (16,10))

ax = sns.heatmap(dfreg.corr(), annot=True, linewidths=.5)

# %%
dfreg['JobTitle'].value_counts()
# Out:
# DBA                                                                                                           1171
# DBA (General - splits time evenly between writing & tuning queries AND building & troubleshooting servers)     698
# Developer: T-SQL                                                                                               418
# Architect                                                                                                      399
# DBA (Production Focus - build & troubleshoot servers, HA/DR)                                                   393
# Developer: Business Intelligence (SSRS, PowerBI, etc)                                                          351
# Developer: App code (C#, JS, etc)                                                                              308
# Manager                                                                                                        294
# ...

# %%
dfreg.groupby(['JobTitle']).Salary_USD.mean().plot(kind='bar')
plt.show()
